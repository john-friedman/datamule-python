# %% [markdown]
# # SEC Submission Metadata
#
# Submissions uploaded to the SEC contain metadata with information about the company and the submission. This metadata is stored in SGML, of which the SEC has two types: archive sgml, and edgar sgml.
#
# ## EDGAR SGML metadata
# ```
# <SEC-DOCUMENT>0000950170-22-000796.txt : 20220207
# <SEC-HEADER>0000950170-22-000796.hdr.sgml : 20220207
# <ACCEPTANCE-DATETIME>20220204201127
# ACCESSION NUMBER:		0000950170-22-000796
# CONFORMED SUBMISSION TYPE:	10-K
# PUBLIC DOCUMENT COUNT:		134
# CONFORMED PERIOD OF REPORT:	20211231
# FILED AS OF DATE:		20220207
# DATE AS OF CHANGE:		20220204
#
# FILER:
#
# 	COMPANY DATA:
# 		COMPANY CONFORMED NAME:			Tesla, Inc.
# 		CENTRAL INDEX KEY:			0001318605
# 		STANDARD INDUSTRIAL CLASSIFICATION:	MOTOR VEHICLES & PASSENGER CAR BODIES [3711]
# 		IRS NUMBER:				912197729
# 		STATE OF INCORPORATION:			DE
# 		FISCAL YEAR END:			1231
#
# 	FILING VALUES:
# 		FORM TYPE:		10-K
# 		SEC ACT:		1934 Act
# 		SEC FILE NUMBER:	001-34756
# 		FILM NUMBER:		22595227
#
# 	BUSINESS ADDRESS:
# 		STREET 1:		3500 DEER CREEK RD
# 		CITY:			PALO ALTO
# 		STATE:			CA
# 		ZIP:			94304
# 		BUSINESS PHONE:		650-681-5000
#
# 	MAIL ADDRESS:
# 		STREET 1:		3500 DEER CREEK RD
# 		CITY:			PALO ALTO
# 		STATE:			CA
# 		ZIP:			94304
#
# 	FORMER COMPANY:
# 		FORMER CONFORMED NAME:	TESLA MOTORS INC
# 		DATE OF NAME CHANGE:	20050222
# </SEC-HEADER>
# ```
#
# ## Archive SGML metadata
# ```
# <SUBMISSION>
# <ACCESSION-NUMBER>0000950170-24-009914
# <TYPE>3
# <PUBLIC-DOCUMENT-COUNT>1
# <PERIOD>20240201
# <FILING-DATE>20240201
# <DATE-OF-FILING-DATE-CHANGE>20240201
# <REPORTING-OWNER>
# <OWNER-DATA>
# <CONFORMED-NAME>THIEL PETER
# <CIK>0001211060
# <ORGANIZATION-NAME>
# </OWNER-DATA>
# <FILING-VALUES>
# <FORM-TYPE>3
# <ACT>34
# <FILE-NUMBER>001-41942
# <FILM-NUMBER>24588225
# </FILING-VALUES>
# <BUSINESS-ADDRESS>
# <STREET1>9200 SUNSET BOULEVARD
# <STREET2>SUITE 1110
# <CITY>WEST HOLLYWOOD
# <STATE>CA
# <ZIP>90069
# <PHONE>323-990-2000
# </BUSINESS-ADDRESS>
# <MAIL-ADDRESS>
# <STREET1>9200 SUNSET BOULEVARD
# <STREET2>SUITE 1110
# <CITY>WEST HOLLYWOOD
# <STATE>CA
# <ZIP>90069
# </MAIL-ADDRESS>
# </REPORTING-OWNER>
# <REPORTING-OWNER>
# <OWNER-DATA>
# <CONFORMED-NAME>Mithril LP
# <CIK>0001552273
# <ORGANIZATION-NAME>
# <STATE-OF-INCORPORATION>DE
# <FISCAL-YEAR-END>1231
# </OWNER-DATA>
# <FILING-VALUES>
# <FORM-TYPE>3
# <ACT>34
# <FILE-NUMBER>001-41942
# <FILM-NUMBER>24588230
# </FILING-VALUES>
# <BUSINESS-ADDRESS>
# <STREET1>ONE LETTERMAN DRIVE
# <STREET2>BUILDING C SUITE 400
# <CITY>SAN FRANCISCO
# <STATE>CA
# <ZIP>94129
# <PHONE>415-248-5147
# </BUSINESS-ADDRESS>
# <MAIL-ADDRESS>
# <STREET1>ONE LETTERMAN DRIVE
# <STREET2>BUILDING C SUITE 400
# <CITY>SAN FRANCISCO
# <STATE>CA
# <ZIP>94129
# </MAIL-ADDRESS>
# </REPORTING-OWNER>
# <REPORTING-OWNER>
# <OWNER-DATA>
# <CONFORMED-NAME>MITHRIL II LP
# <CIK>0001669609
# <ORGANIZATION-NAME>
# <STATE-OF-INCORPORATION>DE
# <FISCAL-YEAR-END>1231
# </OWNER-DATA>
# <FILING-VALUES>
# <FORM-TYPE>3
# <ACT>34
# <FILE-NUMBER>001-41942
# <FILM-NUMBER>24588227
# </FILING-VALUES>
# <BUSINESS-ADDRESS>
# <STREET1>ONE LETTERMAN DRIVE, BLDG. A, SUITE 4900
# <CITY>SAN FRANCISCO
# <STATE>CA
# <ZIP>94129
# <PHONE>(415) 659-8940
# </BUSINESS-ADDRESS>
# <MAIL-ADDRESS>
# <STREET1>ONE LETTERMAN DRIVE, BLDG. A, SUITE 4900
# <CITY>SAN FRANCISCO
# <STATE>CA
# <ZIP>94129
# </MAIL-ADDRESS>
# </REPORTING-OWNER>
# <REPORTING-OWNER>
# <OWNER-DATA>
# <CONFORMED-NAME>Mithril GP LP
# <CIK>0001881891
# <ORGANIZATION-NAME>
# <STATE-OF-INCORPORATION>DE
# <FISCAL-YEAR-END>1231
# </OWNER-DATA>
# <FILING-VALUES>
# <FORM-TYPE>3
# <ACT>34
# <FILE-NUMBER>001-41942
# <FILM-NUMBER>24588226
# </FILING-VALUES>
# <BUSINESS-ADDRESS>
# <STREET1>C/O MITHRIL CAPITAL MANAGEMENT LLC
# <STREET2>600 CONGRESS AVENUE, SUITE 3100
# <CITY>AUSTIN
# <STATE>TX
# <ZIP>78701
# <PHONE>512-717-3770
# </BUSINESS-ADDRESS>
# <MAIL-ADDRESS>
# <STREET1>C/O MITHRIL CAPITAL MANAGEMENT LLC
# <STREET2>600 CONGRESS AVENUE, SUITE 3100
# <CITY>AUSTIN
# <STATE>TX
# <ZIP>78701
# </MAIL-ADDRESS>
# </REPORTING-OWNER>
# <REPORTING-OWNER>
# <OWNER-DATA>
# <CONFORMED-NAME>Mithril II UGP LLC
# <CIK>0001878230
# <ORGANIZATION-NAME>
# <STATE-OF-INCORPORATION>DE
# <FISCAL-YEAR-END>1231
# </OWNER-DATA>
# <FILING-VALUES>
# <FORM-TYPE>3
# <ACT>34
# <FILE-NUMBER>001-41942
# <FILM-NUMBER>24588229
# </FILING-VALUES>
# <BUSINESS-ADDRESS>
# <STREET1>600 CONGRESS AVENUE
# <STREET2>SUITE 3100
# <CITY>AUSTIN
# <STATE>TX
# <ZIP>78701
# <PHONE>512-717-3770
# </BUSINESS-ADDRESS>
# <MAIL-ADDRESS>
# <STREET1>600 CONGRESS AVENUE
# <STREET2>SUITE 3100
# <CITY>AUSTIN
# <STATE>TX
# <ZIP>78701
# </MAIL-ADDRESS>
# </REPORTING-OWNER>
# <REPORTING-OWNER>
# <OWNER-DATA>
# <CONFORMED-NAME>Mithril II GP LP
# <CIK>0001878232
# <ORGANIZATION-NAME>
# <STATE-OF-INCORPORATION>DE
# <FISCAL-YEAR-END>1231
# </OWNER-DATA>
# <FILING-VALUES>
# <FORM-TYPE>3
# <ACT>34
# <FILE-NUMBER>001-41942
# <FILM-NUMBER>24588228
# </FILING-VALUES>
# <BUSINESS-ADDRESS>
# <STREET1>600 CONGRESS AVENUE
# <STREET2>SUITE 3100
# <CITY>AUSTIN
# <STATE>TX
# <ZIP>78701
# <PHONE>512-717-3770
# </BUSINESS-ADDRESS>
# <MAIL-ADDRESS>
# <STREET1>600 CONGRESS AVENUE
# <STREET2>SUITE 3100
# <CITY>AUSTIN
# <STATE>TX
# <ZIP>78701
# </MAIL-ADDRESS>
# </REPORTING-OWNER>
# <ISSUER>
# <COMPANY-DATA>
# <CONFORMED-NAME>Fractyl Health, Inc.
# <CIK>0001572616
# <ASSIGNED-SIC>3841
# <ORGANIZATION-NAME>08 Industrial Applications and Services
# <IRS-NUMBER>273553477
# <STATE-OF-INCORPORATION>DE
# <FISCAL-YEAR-END>1231
# </COMPANY-DATA>
# <BUSINESS-ADDRESS>
# <STREET1>17 HARTWELL AVENUE
# <CITY>LEXINGTON
# <STATE>MA
# <ZIP>02421
# <PHONE>781-902-8800
# </BUSINESS-ADDRESS>
# <MAIL-ADDRESS>
# <STREET1>17 HARTWELL AVENUE
# <CITY>LEXINGTON
# <STATE>MA
# <ZIP>02421
# </MAIL-ADDRESS>
# <FORMER-COMPANY>
# <FORMER-CONFORMED-NAME>Fractyl Laboratories Inc.
# <DATE-CHANGED>20130320
# </FORMER-COMPANY>
# </ISSUER>
# ```
#
# ## Differences between variants
#
# Both EDGAR and archive SGML contain the same information. However, there are differences in key value storage. Archive variant uses dashes, while EDGAR variant uses spaces. Additionally, some values are abbreviated depending on the variant.
#
# ## Datamule's Submission Structure
#
# Datamule parses the SGML submission file and splits them into the individual documents. It also creates a metadata.json file which contains the parsed metadata.
#
# For example, the downloaded file structure for Tesla's 2022 10-K would look like
#
# 000095017022000796/
#
# Metadata:
# * metadata.json
#
# Primary Documents:
# * tsla-20211231.htm (10-K)
# * tsla-ex21_1.htm (EX-21.1)
# * tsla-ex23_1.htm (EX-23.1)
# * tsla-ex31_1.htm (EX-31.1)
# * tsla-ex31_2.htm (EX-31.2)
# * tsla-ex32_1.htm (EX-32.1)
# * img96779317_0.jpg (GRAPHIC)
# ...
#
# Data Files:
# * tsla-20211231_def.xml (EX-101.DEF)
# * tsla-20211231_pre.xml (EX-101.PRE)
# * tsla-20211231_lab.xml (EX-101.LAB)
# * tsla-20211231.xsd (EX-101.SCH)
# * tsla-20211231_cal.xml (EX-101.CAL)
# ...
#
# We'll now look at the metadata.json file for tesla

# %%
from datamule import PremiumDownloader, Downloader

downloader = PremiumDownloader() # Downloader also works, but PremiumDownloader is faster
downloader.download_submissions(submission_type=['10-K'],ticker = 'TSLA', filing_date = ('2022-01-01', '2022-12-31'), output_dir = 'ingest/tesla')
# Out:
# Cost: $0.000010000000 downloads + $0.000007541000 row reads = $0.000017541000
# Balance: $8.208970580000
# Processing files: 100%|██████████| 1/1 [00:04<00:00,  4.33s/it]
# Processing completed in 4.34 seconds

# %% [markdown]
# ## metadata.json
#
# ```
# {
#     "submission": {
#         "ACCESSION-NUMBER": "0000950170-22-000796",
#         "TYPE": "10-K",
#         "PUBLIC-DOCUMENT-COUNT": "134",
#         "PERIOD": "20211231",
#         "FILING-DATE": "20220207",
#         "DATE-OF-FILING-DATE-CHANGE": "20220204",
#         "FILER": {
#             "COMPANY-DATA": {
#                 "CONFORMED-NAME": "Tesla, Inc.",
#                 "CIK": "0001318605",
#                 "ASSIGNED-SIC": "3711",
#                 "IRS-NUMBER": "912197729",
#                 "STATE-OF-INCORPORATION": "DE",
#                 "FISCAL-YEAR-END": "1231"
#             },
#             "FILING-VALUES": {
#                 "FORM-TYPE": "10-K",
#                 "ACT": "34",
#                 "FILE-NUMBER": "001-34756",
#                 "FILM-NUMBER": "22595227"
#             },
#             "BUSINESS-ADDRESS": {
#                 "STREET1": "3500 DEER CREEK RD",
#                 "CITY": "PALO ALTO",
#                 "STATE": "CA",
#                 "ZIP": "94304",
#                 "PHONE": "650-681-5000"
#             },
#             "MAIL-ADDRESS": {
#                 "STREET1": "3500 DEER CREEK RD",
#                 "CITY": "PALO ALTO",
#                 "STATE": "CA",
#                 "ZIP": "94304"
#             },
#             "FORMER-COMPANY": {
#                 "FORMER-CONFORMED-NAME": "TESLA MOTORS INC",
#                 "DATE-CHANGED": "20050222"
#             }
#         }
#     },
#     "documents": [
#         {
#             "TYPE": "10-K",
#             "SEQUENCE": "1",
#             "FILENAME": "tsla-20211231.htm",
#             "DESCRIPTION": "10-K"
#         },
#         {
#             "TYPE": "EX-21.1",
#             "SEQUENCE": "2",
#             "FILENAME": "tsla-ex21_1.htm",
#             "DESCRIPTION": "EX-21.1"
#         },
#         {
#             "TYPE": "EX-23.1",
#             "SEQUENCE": "3",
#             "FILENAME": "tsla-ex23_1.htm",
#             "DESCRIPTION": "EX-23.1"
#         },...
# ```
#
# ## Interacting with metadata using datamule
#
# The easiest way to use metadata in datamule is through the Portfolio class.

# %%
from datamule import Portfolio

# multithreaded to be faster
portfolio = Portfolio('ingest/tesla')

for submission in portfolio:

    # accessing a specific key in the metadata
    print(submission.metadata['submission']['ACCESSION-NUMBER'])
# Out:
# Loading 1 submissions
# Loading submissions: 100%|██████████| 1/1 [00:00<00:00, 102.40it/s]
# 0000950170-22-000796

# %% [markdown]
# Currently the EDGAR and archive metadata variants are not standardized. This is an inconvenience, and I'm looking into harmonizing it. If this is important to your workflow please post a GitHub issue and I'll move it up the priority list.
#
# Lots of things to work on! Last updated 1/1/2025.

# %% [markdown]
# ## Example
#
# Simple Demo for creating a datasets of attachments to 10-K with metadata. Requested via email from a user who wanted an alternative to a product offered by WRDS SEC Suites. If you're reading this, hi :)
#
# The demo will focus on Apple, and will create a csv with:
#
# * filename - the filename of a file in the submission, e.g. a10-kexhibit10202017.htm
# * submission_type - the type of submission, e.g. 10-K
# * document_type - the type of document, e.g. GRAPHIC, EX-22.1, 10-K. (e.g. the form and its attachments)
# * filing_date
# * report_date - reporting period, e.g. 20170930
# * report_year - extracted from first 4 digits of reporting period
# * cik - company's unique identifier
# * ticker - company's current ticker - see cautionary note
# * company_conformed_name - company's name, e.g. APPLE INC

# %%
# Download the data
from datamule import Downloader

downloader = Downloader()

# Download the data
downloader.download_submissions(submission_type=['10-K'],ticker='AAPL',output_dir='ingest/appl_10k')
# Out:
# Progress [Rate: 5.0/s | 0.01 MB/s]: 100%|██████████| 24/24 [00:02<00:00, 10.82it/s]
# Progress [Rate: 6.0/s | 11.96 MB/s]: 100%|██████████| 24/24 [00:04<00:00,  4.86it/s]
# ([], [])

# %%
from datamule import Portfolio, load_package_dataset
import pandas as pd

portfolio = Portfolio('ingest/appl_10k')

# Create lists to store document data
data = []

# Note: You may have to adjust the metadata keys to match the structure of the data
for submission in portfolio:
    metadata = submission.metadata
    sub_info = metadata['submission']
    
    # Extract base submission info
    base_info = {
        'submission_type': sub_info['CONFORMED SUBMISSION TYPE'],
        'filing_date': sub_info['FILED AS OF DATE'],
        'report_date': sub_info['CONFORMED PERIOD OF REPORT'],
        'report_year': sub_info['CONFORMED PERIOD OF REPORT'][:4],
        'cik': sub_info['FILER']['COMPANY DATA']['CENTRAL INDEX KEY'],
        'company_conformed_name': sub_info['FILER']['COMPANY DATA']['COMPANY CONFORMED NAME'],
    }
    
    # Add each document with the base info
    for doc in metadata['documents']:  # documents is at root level
        row = base_info.copy()
        row['filename'] = doc['FILENAME']
        row['document_type'] = doc['TYPE']
        data.append(row)

# Create DataFrame and save to CSV
df = pd.DataFrame(data)
df = df[['filename', 'submission_type', 'document_type', 'filing_date', 
         'report_date', 'report_year', 'cik', 'company_conformed_name']]

# now we merge in ticker data
ticker_df = pd.DataFrame(load_package_dataset('company_tickers')) # dataset is stored as a list of dictionaries so as to allow alternatives to pandas, like polars.
ticker_df = ticker_df[['cik', 'ticker']]
df = df.merge(ticker_df, on='cik', how='left')

df.to_csv('data/apple_10k_attachments.csv', index=False)
# Out:
# Loading 24 submissions
# Loading submissions: 100%|██████████| 24/24 [00:00<00:00, 196.75it/s]

# %% [markdown]
# ##  Conclusion
#
# You can view the sample data [here](https://github.com/john-friedman/datamule-python/blob/main/examples/data/apple_10k_attachments.csv).
#
#
# Cautionary note: Tickers change over time. `company_tickers` dataset is based on the current SEC provided ticker dataset.
